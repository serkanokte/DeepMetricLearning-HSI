# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings("ignore")

# !pip install metric-learn

from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from metric_learn import MMC_Supervised
# Out:
# Collecting metric-learn
#   Downloading metric_learn-0.7.0-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 793.3 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from metric-learn) (1.25.2)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from metric-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from metric-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->metric-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->metric-learn) (3.5.0)
# Installing collected packages: metric-learn
# Successfully installed metric-learn-0.7.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import scipy.io
data = scipy.io.loadmat('/content/drive/MyDrive/dml/Pavia-veriseti/PaviaU.mat')['paviaU']
gt = scipy.io.loadmat('/content/drive/MyDrive/dml/Pavia-veriseti/PaviaU_gt.mat')['paviaU_gt']

def applyPCA(X, numComponents=15):
    newX = np.reshape(X, (-1, X.shape[2]))
    pca = PCA(n_components=numComponents, whiten=True)
    newX = pca.fit_transform(newX)
    newX = np.reshape(newX, (X.shape[0],X.shape[1], numComponents))
    return newX

data=applyPCA(data)

df = pd.DataFrame(data.reshape(data.shape[0]*data.shape[1], -1))
df['class'] = gt.ravel()

X = df[df['class']!=0].iloc[:, :-1].values

y = df[df['class']!=0].iloc[:, -1].values

# %%
acc_list = []

kf = KFold(n_splits=5, shuffle=True,random_state=42)

mmc = MMC_Supervised(n_constraints=5,verbose=True)
knn = KNeighborsClassifier(n_neighbors=5)

f_index = 1
for train_index, test_index in kf.split(X):
    print(f"Fold {f_index} -> Train: {len(train_index)}, Test: {len(test_index)}")

    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    mmc.fit(X_train, y_train)
    knn.fit(mmc.transform(X_train), y_train)


    mmc_acc = knn.score(mmc.transform(X_test), y_test)
    print('mmc accuracy  {}'.format(mmc_acc))

    acc_list.append(mmc_acc)

    f_index += 1

print("Ortalaması Başarı:", np.mean(acc_list))
print("Standart sapma:",np.std(acc_list) )
# Out:
# Fold 1 -> Train: 34220, Test: 8556
# mmc iter: 0, conv = 0.033128, projections = 674
# mmc iter: 1, conv = 0.034251, projections = 321
# mmc iter: 2, conv = 0.035372, projections = 324
# mmc iter: 3, conv = 0.036486, projections = 315
# mmc iter: 4, conv = 0.037590, projections = 304
# mmc iter: 5, conv = 0.038680, projections = 295
# mmc iter: 6, conv = 0.039753, projections = 288
# mmc iter: 7, conv = 0.040804, projections = 283
# mmc iter: 8, conv = 0.041831, projections = 279
# mmc iter: 9, conv = 0.042831, projections = 276
# mmc iter: 10, conv = 0.043802, projections = 274
# mmc iter: 11, conv = 0.044740, projections = 273
# mmc iter: 12, conv = 0.045655, projections = 488
# mmc iter: 13, conv = 0.046552, projections = 624
# mmc iter: 14, conv = 0.047426, projections = 747
# mmc iter: 15, conv = 0.048277, projections = 870
# mmc iter: 16, conv = 0.049104, projections = 986
# mmc iter: 17, conv = 0.049906, projections = 1093
# mmc iter: 18, conv = 0.050680, projections = 1191
# mmc iter: 19, conv = 0.051427, projections = 1283
# mmc iter: 20, conv = 0.052145, projections = 1372
# mmc iter: 21, conv = 0.052835, projections = 1459
# mmc iter: 22, conv = 0.053496, projections = 1548
# mmc iter: 23, conv = 0.054130, projections = 1639
# mmc iter: 24, conv = 0.054736, projections = 1733
# mmc iter: 25, conv = 0.055315, projections = 1832
# mmc iter: 26, conv = 0.055868, projections = 1934
# mmc iter: 27, conv = 0.056395, projections = 2042
# mmc iter: 28, conv = 0.056898, projections = 2154
# mmc iter: 29, conv = 0.057377, projections = 2273
# mmc iter: 30, conv = 0.057834, projections = 2398
# mmc iter: 31, conv = 0.058269, projections = 2530
# mmc iter: 32, conv = 0.058683, projections = 2669
# mmc iter: 33, conv = 0.059077, projections = 2815
# mmc iter: 34, conv = 0.059452, projections = 2969
# mmc iter: 35, conv = 0.059809, projections = 3132
# mmc iter: 36, conv = 0.060150, projections = 3304
# mmc iter: 37, conv = 0.060474, projections = 3485
# mmc iter: 38, conv = 0.060783, projections = 3676
# mmc iter: 39, conv = 0.061078, projections = 3877
# mmc iter: 40, conv = 0.061359, projections = 4089
# mmc iter: 41, conv = 0.061628, projections = 4314
# mmc iter: 42, conv = 0.061884, projections = 4550
# mmc iter: 43, conv = 0.062128, projections = 4799
# mmc iter: 44, conv = 0.062362, projections = 5062
# mmc iter: 45, conv = 0.062586, projections = 5340
# mmc iter: 46, conv = 0.062800, projections = 5632
# mmc iter: 47, conv = 0.063006, projections = 5941
# mmc iter: 48, conv = 0.063202, projections = 6266
# mmc iter: 49, conv = 0.063391, projections = 6610
# mmc iter: 50, conv = 0.063572, projections = 6972
# mmc iter: 51, conv = 0.063746, projections = 7354
# mmc iter: 52, conv = 0.063913, projections = 7757
# mmc iter: 53, conv = 0.064074, projections = 8181
# mmc iter: 54, conv = 0.064228, projections = 8630
# mmc iter: 55, conv = 0.064377, projections = 9102
# mmc iter: 56, conv = 0.064521, projections = 9601
# mmc iter: 57, conv = 0.032260, projections = 10000
# mmc iter: 58, conv = 0.033086, projections = 8401
# mmc iter: 59, conv = 0.033912, projections = 8490
# mmc iter: 60, conv = 0.034738, projections = 8704
# mmc iter: 61, conv = 0.035563, projections = 8976
# mmc iter: 62, conv = 0.036386, projections = 9284
# mmc iter: 63, conv = 0.037207, projections = 9621
# mmc iter: 64, conv = 0.038023, projections = 9982
# mmc iter: 65, conv = 0.019012, projections = 10000
# mmc iter: 66, conv = 0.019687, projections = 8583
# mmc iter: 67, conv = 0.020376, projections = 8587
# mmc iter: 68, conv = 0.021078, projections = 8721
# mmc iter: 69, conv = 0.021794, projections = 8914
# mmc iter: 70, conv = 0.022522, projections = 9141
# mmc iter: 71, conv = 0.023263, projections = 9393
# mmc iter: 72, conv = 0.024014, projections = 9665
# mmc iter: 73, conv = 0.024777, projections = 9957
# mmc iter: 74, conv = 0.012389, projections = 10000
# mmc iter: 75, conv = 0.012891, projections = 8491
# mmc iter: 76, conv = 0.013408, projections = 8479
# mmc iter: 77, conv = 0.013941, projections = 8571
# mmc iter: 78, conv = 0.014490, projections = 8719
# mmc iter: 79, conv = 0.015054, projections = 8899
# mmc iter: 80, conv = 0.015634, projections = 9102
# mmc iter: 81, conv = 0.016229, projections = 9323
# mmc iter: 82, conv = 0.016839, projections = 9559
# mmc iter: 83, conv = 0.017465, projections = 9810
# mmc iter: 84, conv = 0.008733, projections = 10000
# mmc iter: 85, conv = 0.009111, projections = 8302
# mmc iter: 86, conv = 0.009503, projections = 8309
# mmc iter: 87, conv = 0.009909, projections = 8388
# mmc iter: 88, conv = 0.010329, projections = 8513
# mmc iter: 89, conv = 0.010764, projections = 8667
# mmc iter: 90, conv = 0.011214, projections = 8841
# mmc iter: 91, conv = 0.011678, projections = 9031
# mmc iter: 92, conv = 0.012158, projections = 9235
# mmc iter: 93, conv = 0.012653, projections = 9450
# mmc iter: 94, conv = 0.013163, projections = 9677
# mmc iter: 95, conv = 0.013689, projections = 9916
# mmc iter: 96, conv = 0.006844, projections = 10000
# mmc iter: 97, conv = 0.007151, projections = 8335
# mmc iter: 98, conv = 0.007469, projections = 8366
# mmc iter: 99, conv = 0.007800, projections = 8449
# mmc did not converge, conv = 0.007800
# mmc accuracy  0.8233987844787284
# Fold 2 -> Train: 34221, Test: 8555
# mmc iter: 0, conv = 0.033059, projections = 1224
# mmc iter: 1, conv = 0.034362, projections = 523
# mmc iter: 2, conv = 0.035689, projections = 475
# mmc iter: 3, conv = 0.037034, projections = 435
# mmc iter: 4, conv = 0.038396, projections = 405
# mmc iter: 5, conv = 0.039772, projections = 385
# mmc iter: 6, conv = 0.041159, projections = 370
# mmc iter: 7, conv = 0.042555, projections = 359
# mmc iter: 8, conv = 0.043956, projections = 352
# mmc iter: 9, conv = 0.045358, projections = 346
# mmc iter: 10, conv = 0.046760, projections = 342
# mmc iter: 11, conv = 0.048156, projections = 340
# mmc iter: 12, conv = 0.049544, projections = 339
# mmc iter: 13, conv = 0.050920, projections = 340
# mmc iter: 14, conv = 0.052294, projections = 477
# mmc iter: 15, conv = 0.053665, projections = 549
# mmc iter: 16, conv = 0.055028, projections = 625
# mmc iter: 17, conv = 0.056383, projections = 708
# mmc iter: 18, conv = 0.057728, projections = 797
# mmc iter: 19, conv = 0.059061, projections = 892
# mmc iter: 20, conv = 0.060380, projections = 991
# mmc iter: 21, conv = 0.061682, projections = 1092
# mmc iter: 22, conv = 0.062966, projections = 1193
# mmc iter: 23, conv = 0.064228, projections = 1294
# mmc iter: 24, conv = 0.065467, projections = 1396
# mmc iter: 25, conv = 0.066681, projections = 1497
# mmc iter: 26, conv = 0.067868, projections = 1599
# mmc iter: 27, conv = 0.069027, projections = 1703
# mmc iter: 28, conv = 0.070156, projections = 1810
# mmc iter: 29, conv = 0.071255, projections = 1920
# mmc iter: 30, conv = 0.072323, projections = 2034
# mmc iter: 31, conv = 0.073358, projections = 2154
# mmc iter: 32, conv = 0.074361, projections = 2279
# mmc iter: 33, conv = 0.075333, projections = 2410
# mmc iter: 34, conv = 0.076271, projections = 2548
# mmc iter: 35, conv = 0.077178, projections = 2694
# mmc iter: 36, conv = 0.078053, projections = 2848
# mmc iter: 37, conv = 0.078897, projections = 3011
# mmc iter: 38, conv = 0.079709, projections = 3183
# mmc iter: 39, conv = 0.080492, projections = 3364
# mmc iter: 40, conv = 0.081244, projections = 3556
# mmc iter: 41, conv = 0.081968, projections = 3759
# mmc iter: 42, conv = 0.082664, projections = 3974
# mmc iter: 43, conv = 0.083332, projections = 4201
# mmc iter: 44, conv = 0.083974, projections = 4441
# mmc iter: 45, conv = 0.084591, projections = 4695
# mmc iter: 46, conv = 0.085183, projections = 4964
# mmc iter: 47, conv = 0.085751, projections = 5248
# mmc iter: 48, conv = 0.086296, projections = 5548
# mmc iter: 49, conv = 0.086819, projections = 5865
# mmc iter: 50, conv = 0.087320, projections = 6200
# mmc iter: 51, conv = 0.087802, projections = 6554
# mmc iter: 52, conv = 0.088263, projections = 6928
# mmc iter: 53, conv = 0.088707, projections = 7324
# mmc iter: 54, conv = 0.089132, projections = 7742
# mmc iter: 55, conv = 0.089540, projections = 8183
# mmc iter: 56, conv = 0.089931, projections = 8650
# mmc iter: 57, conv = 0.090307, projections = 9142
# mmc iter: 58, conv = 0.090668, projections = 9663
# mmc iter: 59, conv = 0.045334, projections = 10000
# mmc iter: 60, conv = 0.046542, projections = 8152
# mmc iter: 61, conv = 0.047752, projections = 8020
# mmc iter: 62, conv = 0.048962, projections = 8122
# mmc iter: 63, conv = 0.050173, projections = 8336
# mmc iter: 64, conv = 0.051382, projections = 8616
# mmc iter: 65, conv = 0.052589, projections = 8940
# mmc iter: 66, conv = 0.053792, projections = 9298
# mmc iter: 67, conv = 0.054990, projections = 9686
# mmc iter: 68, conv = 0.027495, projections = 10000
# mmc iter: 69, conv = 0.028478, projections = 8276
# mmc iter: 70, conv = 0.029482, projections = 8115
# mmc iter: 71, conv = 0.030505, projections = 8143
# mmc iter: 72, conv = 0.031547, projections = 8264
# mmc iter: 73, conv = 0.032608, projections = 8446
# mmc iter: 74, conv = 0.033687, projections = 8670
# mmc iter: 75, conv = 0.034783, projections = 8928
# mmc iter: 76, conv = 0.035895, projections = 9215
# mmc iter: 77, conv = 0.037022, projections = 9526
# mmc iter: 78, conv = 0.038163, projections = 9861
# mmc iter: 79, conv = 0.019081, projections = 10000
# mmc iter: 80, conv = 0.019846, projections = 8496
# mmc iter: 81, conv = 0.020634, projections = 8353
# mmc iter: 82, conv = 0.021444, projections = 8366
# mmc iter: 83, conv = 0.022277, projections = 8458
# mmc iter: 84, conv = 0.023133, projections = 8600
# mmc iter: 85, conv = 0.024012, projections = 8780
# mmc iter: 86, conv = 0.024913, projections = 8990
# mmc iter: 87, conv = 0.025836, projections = 9226
# mmc iter: 88, conv = 0.026781, projections = 9485
# mmc iter: 89, conv = 0.027747, projections = 9766
# mmc iter: 90, conv = 0.013874, projections = 10000
# mmc iter: 91, conv = 0.014467, projections = 8443
# mmc iter: 92, conv = 0.015082, projections = 8336
# mmc iter: 93, conv = 0.015717, projections = 8348
# mmc iter: 94, conv = 0.016375, projections = 8425
# mmc iter: 95, conv = 0.017054, projections = 8544
# mmc iter: 96, conv = 0.017755, projections = 8693
# mmc iter: 97, conv = 0.018479, projections = 8868
# mmc iter: 98, conv = 0.019225, projections = 9064
# mmc iter: 99, conv = 0.019994, projections = 9280
# mmc did not converge, conv = 0.019994
# mmc accuracy  0.8054938632378726
# Fold 3 -> Train: 34221, Test: 8555
# mmc iter: 0, conv = 0.032826, projections = 3465
# mmc iter: 1, conv = 0.034040, projections = 1324
# mmc iter: 2, conv = 0.035264, projections = 1191
# mmc iter: 3, conv = 0.036490, projections = 1082
# mmc iter: 4, conv = 0.037714, projections = 1007
# mmc iter: 5, conv = 0.038932, projections = 955
# mmc iter: 6, conv = 0.040141, projections = 916
# mmc iter: 7, conv = 0.041335, projections = 887
# mmc iter: 8, conv = 0.042510, projections = 865
# mmc iter: 9, conv = 0.043664, projections = 849
# mmc iter: 10, conv = 0.044792, projections = 836
# mmc iter: 11, conv = 0.045890, projections = 827
# mmc iter: 12, conv = 0.046956, projections = 821
# mmc iter: 13, conv = 0.047987, projections = 818
# mmc iter: 14, conv = 0.048979, projections = 816
# mmc iter: 15, conv = 0.049931, projections = 817
# mmc iter: 16, conv = 0.050842, projections = 820
# mmc iter: 17, conv = 0.051710, projections = 826
# mmc iter: 18, conv = 0.052535, projections = 833
# mmc iter: 19, conv = 0.053322, projections = 1023
# mmc iter: 20, conv = 0.054077, projections = 1174
# mmc iter: 21, conv = 0.054798, projections = 1311
# mmc iter: 22, conv = 0.055485, projections = 1459
# mmc iter: 23, conv = 0.056138, projections = 1621
# mmc iter: 24, conv = 0.056759, projections = 1799
# mmc iter: 25, conv = 0.057350, projections = 1996
# mmc iter: 26, conv = 0.057910, projections = 2214
# mmc iter: 27, conv = 0.058443, projections = 2454
# mmc iter: 28, conv = 0.058948, projections = 2717
# mmc iter: 29, conv = 0.059428, projections = 3006
# mmc iter: 30, conv = 0.059883, projections = 3320
# mmc iter: 31, conv = 0.060315, projections = 3662
# mmc iter: 32, conv = 0.060725, projections = 4031
# mmc iter: 33, conv = 0.061114, projections = 4428
# mmc iter: 34, conv = 0.061484, projections = 4854
# mmc iter: 35, conv = 0.061836, projections = 5310
# mmc iter: 36, conv = 0.062169, projections = 5797
# mmc iter: 37, conv = 0.062487, projections = 6316
# mmc iter: 38, conv = 0.062789, projections = 6870
# mmc iter: 39, conv = 0.063076, projections = 7459
# mmc iter: 40, conv = 0.063350, projections = 8088
# mmc iter: 41, conv = 0.063611, projections = 8757
# mmc iter: 42, conv = 0.063860, projections = 9471
# mmc iter: 43, conv = 0.031930, projections = 10000
# mmc iter: 44, conv = 0.032777, projections = 8392
# mmc iter: 45, conv = 0.033625, projections = 8408
# mmc iter: 46, conv = 0.034474, projections = 8566
# mmc iter: 47, conv = 0.035322, projections = 8807
# mmc iter: 48, conv = 0.036169, projections = 9108
# mmc iter: 49, conv = 0.037014, projections = 9458
# mmc iter: 50, conv = 0.037856, projections = 9853
# mmc iter: 51, conv = 0.018928, projections = 10000
# mmc iter: 52, conv = 0.019609, projections = 8588
# mmc iter: 53, conv = 0.020304, projections = 8586
# mmc iter: 54, conv = 0.021013, projections = 8673
# mmc iter: 55, conv = 0.021736, projections = 8818
# mmc iter: 56, conv = 0.022472, projections = 9006
# mmc iter: 57, conv = 0.023220, projections = 9228
# mmc iter: 58, conv = 0.023981, projections = 9481
# mmc iter: 59, conv = 0.024754, projections = 9763
# mmc iter: 60, conv = 0.012377, projections = 10000
# mmc iter: 61, conv = 0.012882, projections = 8376
# mmc iter: 62, conv = 0.013402, projections = 8413
# mmc iter: 63, conv = 0.013938, projections = 8501
# mmc iter: 64, conv = 0.014490, projections = 8625
# mmc iter: 65, conv = 0.015058, projections = 8775
# mmc iter: 66, conv = 0.015642, projections = 8949
# mmc iter: 67, conv = 0.016242, projections = 9144
# mmc iter: 68, conv = 0.016858, projections = 9358
# mmc iter: 69, conv = 0.017489, projections = 9592
# mmc iter: 70, conv = 0.018136, projections = 9844
# mmc iter: 71, conv = 0.009068, projections = 10000
# mmc iter: 72, conv = 0.009460, projections = 8323
# mmc iter: 73, conv = 0.009866, projections = 8395
# mmc iter: 74, conv = 0.010287, projections = 8500
# mmc iter: 75, conv = 0.010722, projections = 8629
# mmc iter: 76, conv = 0.011172, projections = 8777
# mmc iter: 77, conv = 0.011638, projections = 8941
# mmc iter: 78, conv = 0.012119, projections = 9121
# mmc iter: 79, conv = 0.012615, projections = 9315
# mmc iter: 80, conv = 0.013127, projections = 9524
# mmc iter: 81, conv = 0.013655, projections = 9746
# mmc iter: 82, conv = 0.014199, projections = 9984
# mmc iter: 83, conv = 0.007099, projections = 10000
# mmc iter: 84, conv = 0.007417, projections = 8325
# mmc iter: 85, conv = 0.007746, projections = 8422
# mmc iter: 86, conv = 0.008089, projections = 8542
# mmc iter: 87, conv = 0.008444, projections = 8679
# mmc iter: 88, conv = 0.008813, projections = 8830
# mmc iter: 89, conv = 0.009196, projections = 8995
# mmc iter: 90, conv = 0.009593, projections = 9171
# mmc iter: 91, conv = 0.010004, projections = 9359
# mmc iter: 92, conv = 0.010429, projections = 9557
# mmc iter: 93, conv = 0.010869, projections = 9768
# mmc iter: 94, conv = 0.011325, projections = 9989
# mmc iter: 95, conv = 0.005662, projections = 10000
# mmc iter: 96, conv = 0.005921, projections = 8206
# mmc iter: 97, conv = 0.006191, projections = 8321
# mmc iter: 98, conv = 0.006472, projections = 8453
# mmc iter: 99, conv = 0.006765, projections = 8597
# mmc did not converge, conv = 0.006765
# mmc accuracy  0.8668614845119813
# Fold 4 -> Train: 34221, Test: 8555
# mmc iter: 0, conv = 0.033121, projections = 793
# mmc iter: 1, conv = 0.034223, projections = 177
# mmc iter: 2, conv = 0.035323, projections = 258
# mmc iter: 3, conv = 0.036413, projections = 256
# mmc iter: 4, conv = 0.037489, projections = 244
# mmc iter: 5, conv = 0.038547, projections = 232
# mmc iter: 6, conv = 0.039582, projections = 221
# mmc iter: 7, conv = 0.040593, projections = 213
# mmc iter: 8, conv = 0.041574, projections = 208
# mmc iter: 9, conv = 0.042527, projections = 261
# mmc iter: 10, conv = 0.043461, projections = 361
# mmc iter: 11, conv = 0.044369, projections = 402
# mmc iter: 12, conv = 0.045249, projections = 440
# mmc iter: 13, conv = 0.046098, projections = 477
# mmc iter: 14, conv = 0.046915, projections = 513
# mmc iter: 15, conv = 0.047699, projections = 548
# mmc iter: 16, conv = 0.048451, projections = 584
# mmc iter: 17, conv = 0.049168, projections = 620
# mmc iter: 18, conv = 0.049851, projections = 658
# mmc iter: 19, conv = 0.050501, projections = 697
# mmc iter: 20, conv = 0.051117, projections = 738
# mmc iter: 21, conv = 0.051700, projections = 781
# mmc iter: 22, conv = 0.052251, projections = 826
# mmc iter: 23, conv = 0.052771, projections = 874
# mmc iter: 24, conv = 0.053261, projections = 925
# mmc iter: 25, conv = 0.053722, projections = 978
# mmc iter: 26, conv = 0.054154, projections = 1035
# mmc iter: 27, conv = 0.054561, projections = 1094
# mmc iter: 28, conv = 0.054942, projections = 1158
# mmc iter: 29, conv = 0.055299, projections = 1225
# mmc iter: 30, conv = 0.055633, projections = 1296
# mmc iter: 31, conv = 0.055946, projections = 1371
# mmc iter: 32, conv = 0.056239, projections = 1450
# mmc iter: 33, conv = 0.056513, projections = 1535
# mmc iter: 34, conv = 0.056769, projections = 1624
# mmc iter: 35, conv = 0.057008, projections = 1718
# mmc iter: 36, conv = 0.057232, projections = 1818
# mmc iter: 37, conv = 0.057441, projections = 1924
# mmc iter: 38, conv = 0.057637, projections = 2035
# mmc iter: 39, conv = 0.057821, projections = 2154
# mmc iter: 40, conv = 0.057993, projections = 2279
# mmc iter: 41, conv = 0.058154, projections = 2412
# mmc iter: 42, conv = 0.058304, projections = 2552
# mmc iter: 43, conv = 0.058446, projections = 2701
# mmc iter: 44, conv = 0.058579, projections = 2858
# mmc iter: 45, conv = 0.058704, projections = 3025
# mmc iter: 46, conv = 0.058821, projections = 3201
# mmc iter: 47, conv = 0.058932, projections = 3387
# mmc iter: 48, conv = 0.059036, projections = 3584
# mmc iter: 49, conv = 0.059134, projections = 3793
# mmc iter: 50, conv = 0.059226, projections = 4014
# mmc iter: 51, conv = 0.059314, projections = 4248
# mmc iter: 52, conv = 0.059397, projections = 4495
# mmc iter: 53, conv = 0.059475, projections = 4757
# mmc iter: 54, conv = 0.059550, projections = 5034
# mmc iter: 55, conv = 0.059620, projections = 5327
# mmc iter: 56, conv = 0.059687, projections = 5637
# mmc iter: 57, conv = 0.059751, projections = 5965
# mmc iter: 58, conv = 0.059812, projections = 6313
# mmc iter: 59, conv = 0.059870, projections = 6680
# mmc iter: 60, conv = 0.059925, projections = 7069
# mmc iter: 61, conv = 0.059978, projections = 7480
# mmc iter: 62, conv = 0.060029, projections = 7915
# mmc iter: 63, conv = 0.060077, projections = 8376
# mmc iter: 64, conv = 0.060123, projections = 8863
# mmc iter: 65, conv = 0.060168, projections = 9379
# mmc iter: 66, conv = 0.060211, projections = 9925
# mmc iter: 67, conv = 0.030105, projections = 10000
# mmc iter: 68, conv = 0.030852, projections = 9172
# mmc iter: 69, conv = 0.031599, projections = 9321
# mmc iter: 70, conv = 0.032344, projections = 9558
# mmc iter: 71, conv = 0.033088, projections = 9842
# mmc iter: 72, conv = 0.016544, projections = 10000
# mmc iter: 73, conv = 0.017140, projections = 8831
# mmc iter: 74, conv = 0.017749, projections = 8900
# mmc iter: 75, conv = 0.018370, projections = 9035
# mmc iter: 76, conv = 0.019004, projections = 9207
# mmc iter: 77, conv = 0.019650, projections = 9403
# mmc iter: 78, conv = 0.020307, projections = 9619
# mmc iter: 79, conv = 0.020975, projections = 9851
# mmc iter: 80, conv = 0.010487, projections = 10000
# mmc iter: 81, conv = 0.010919, projections = 8674
# mmc iter: 82, conv = 0.011363, projections = 8745
# mmc iter: 83, conv = 0.011822, projections = 8860
# mmc iter: 84, conv = 0.012295, projections = 9002
# mmc iter: 85, conv = 0.012781, projections = 9162
# mmc iter: 86, conv = 0.013282, projections = 9337
# mmc iter: 87, conv = 0.013797, projections = 9524
# mmc iter: 88, conv = 0.014326, projections = 9721
# mmc iter: 89, conv = 0.014868, projections = 9930
# mmc iter: 90, conv = 0.007434, projections = 10000
# mmc iter: 91, conv = 0.007759, projections = 8608
# mmc iter: 92, conv = 0.008096, projections = 8690
# mmc iter: 93, conv = 0.008445, projections = 8804
# mmc iter: 94, conv = 0.008806, projections = 8939
# mmc iter: 95, conv = 0.009181, projections = 9088
# mmc iter: 96, conv = 0.009568, projections = 9248
# mmc iter: 97, conv = 0.009969, projections = 9418
# mmc iter: 98, conv = 0.010383, projections = 9596
# mmc iter: 99, conv = 0.010811, projections = 9783
# mmc did not converge, conv = 0.010811
# mmc accuracy  0.8139099941554646
# Fold 5 -> Train: 34221, Test: 8555
# mmc iter: 0, conv = 0.033121, projections = 712
# mmc iter: 1, conv = 0.034331, projections = 211
# mmc iter: 2, conv = 0.035546, projections = 281
# mmc iter: 3, conv = 0.036757, projections = 276
# mmc iter: 4, conv = 0.037959, projections = 261
# mmc iter: 5, conv = 0.039147, projections = 246
# mmc iter: 6, conv = 0.040316, projections = 233
# mmc iter: 7, conv = 0.041462, projections = 223
# mmc iter: 8, conv = 0.042580, projections = 216
# mmc iter: 9, conv = 0.043679, projections = 344
# mmc iter: 10, conv = 0.044761, projections = 411
# mmc iter: 11, conv = 0.045820, projections = 466
# mmc iter: 12, conv = 0.046854, projections = 526
# mmc iter: 13, conv = 0.047861, projections = 590
# mmc iter: 14, conv = 0.048841, projections = 658
# mmc iter: 15, conv = 0.049792, projections = 730
# mmc iter: 16, conv = 0.050712, projections = 805
# mmc iter: 17, conv = 0.051602, projections = 882
# mmc iter: 18, conv = 0.052461, projections = 962
# mmc iter: 19, conv = 0.053287, projections = 1044
# mmc iter: 20, conv = 0.054081, projections = 1129
# mmc iter: 21, conv = 0.054843, projections = 1217
# mmc iter: 22, conv = 0.055573, projections = 1307
# mmc iter: 23, conv = 0.056271, projections = 1401
# mmc iter: 24, conv = 0.056938, projections = 1499
# mmc iter: 25, conv = 0.057574, projections = 1602
# mmc iter: 26, conv = 0.058180, projections = 1709
# mmc iter: 27, conv = 0.058758, projections = 1822
# mmc iter: 28, conv = 0.059307, projections = 1940
# mmc iter: 29, conv = 0.059830, projections = 2065
# mmc iter: 30, conv = 0.060327, projections = 2197
# mmc iter: 31, conv = 0.060799, projections = 2336
# mmc iter: 32, conv = 0.061247, projections = 2483
# mmc iter: 33, conv = 0.061673, projections = 2639
# mmc iter: 34, conv = 0.062078, projections = 2804
# mmc iter: 35, conv = 0.062463, projections = 2978
# mmc iter: 36, conv = 0.062828, projections = 3162
# mmc iter: 37, conv = 0.063175, projections = 3357
# mmc iter: 38, conv = 0.063505, projections = 3564
# mmc iter: 39, conv = 0.063818, projections = 3783
# mmc iter: 40, conv = 0.064117, projections = 4015
# mmc iter: 41, conv = 0.064401, projections = 4261
# mmc iter: 42, conv = 0.064671, projections = 4521
# mmc iter: 43, conv = 0.064929, projections = 4797
# mmc iter: 44, conv = 0.065174, projections = 5089
# mmc iter: 45, conv = 0.065408, projections = 5398
# mmc iter: 46, conv = 0.065631, projections = 5725
# mmc iter: 47, conv = 0.065845, projections = 6073
# mmc iter: 48, conv = 0.066048, projections = 6440
# mmc iter: 49, conv = 0.066243, projections = 6830
# mmc iter: 50, conv = 0.066430, projections = 7242
# mmc iter: 51, conv = 0.066608, projections = 7679
# mmc iter: 52, conv = 0.066779, projections = 8142
# mmc iter: 53, conv = 0.066942, projections = 8633
# mmc iter: 54, conv = 0.067099, projections = 9152
# mmc iter: 55, conv = 0.067250, projections = 9702
# mmc iter: 56, conv = 0.033625, projections = 10000
# mmc iter: 57, conv = 0.034488, projections = 8586
# mmc iter: 58, conv = 0.035350, projections = 8621
# mmc iter: 59, conv = 0.036212, projections = 8800
# mmc iter: 60, conv = 0.037073, projections = 9051
# mmc iter: 61, conv = 0.037932, projections = 9349
# mmc iter: 62, conv = 0.038788, projections = 9683
# mmc iter: 63, conv = 0.019394, projections = 10000
# mmc iter: 64, conv = 0.020089, projections = 8456
# mmc iter: 65, conv = 0.020799, projections = 8448
# mmc iter: 66, conv = 0.021523, projections = 8547
# mmc iter: 67, conv = 0.022261, projections = 8705
# mmc iter: 68, conv = 0.023012, projections = 8900
# mmc iter: 69, conv = 0.023776, projections = 9124
# mmc iter: 70, conv = 0.024553, projections = 9371
# mmc iter: 71, conv = 0.025341, projections = 9641
# mmc iter: 72, conv = 0.026140, projections = 9930
# mmc iter: 73, conv = 0.013070, projections = 10000
# mmc iter: 74, conv = 0.013598, projections = 8599
# mmc iter: 75, conv = 0.014143, projections = 8609
# mmc iter: 76, conv = 0.014704, projections = 8697
# mmc iter: 77, conv = 0.015280, projections = 8833
# mmc iter: 78, conv = 0.015873, projections = 8999
# mmc iter: 79, conv = 0.016483, projections = 9188
# mmc iter: 80, conv = 0.017108, projections = 9398
# mmc iter: 81, conv = 0.017749, projections = 9624
# mmc iter: 82, conv = 0.018406, projections = 9866
# mmc iter: 83, conv = 0.009203, projections = 10000
# mmc iter: 84, conv = 0.009601, projections = 8439
# mmc iter: 85, conv = 0.010013, projections = 8471
# mmc iter: 86, conv = 0.010440, projections = 8560
# mmc iter: 87, conv = 0.010882, projections = 8683
# mmc iter: 88, conv = 0.011340, projections = 8830
# mmc iter: 89, conv = 0.011812, projections = 8995
# mmc iter: 90, conv = 0.012301, projections = 9176
# mmc iter: 91, conv = 0.012805, projections = 9370
# mmc iter: 92, conv = 0.013325, projections = 9578
# mmc iter: 93, conv = 0.013861, projections = 9797
# mmc iter: 94, conv = 0.006930, projections = 10000
# mmc iter: 95, conv = 0.007242, projections = 8280
# mmc iter: 96, conv = 0.007565, projections = 8332
# mmc iter: 97, conv = 0.007901, projections = 8429
# mmc iter: 98, conv = 0.008251, projections = 8552
# mmc iter: 99, conv = 0.008613, projections = 8692
# mmc did not converge, conv = 0.008613
# mmc accuracy  0.8839275277615429
# Ortalaması Başarı: 0.838718330829118
# Standart sapma: 0.0309513033719384

# %%
import joblib

joblib.dump(mmc, 'mmc_pavia_model.pkl')
joblib.dump(knn,'mmc_pavia_knn_model.pkl')

mmc_loaded = joblib.load('mmc_pavia_model.pkl')
knn_loaded =joblib.load('mmc_pavia_knn_model.pkl')

mmc_data=mmc_loaded.transform(X)
pred=knn_loaded.predict(mmc_data)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score

print("accuracy:",accuracy_score(pred,y))
print("cohen kappa:", cohen_kappa_score(pred,y))
print("f1 score:",f1_score(pred,y,average='macro'))

# %%
gt_2 = gt.copy()
gt_2=gt_2.reshape(-1)


i = 0
j=0
while(i<(gt.shape[0]*gt.shape[1])):
      if(gt_2[i] != 0):
          gt_2[i]=pred[j]
          j += 1
      i += 1

# %%
gt_2=gt_2.reshape(data.shape[0],-1)

# %%
def plot_gt(data):
  fig = plt.figure(figsize=(12, 8))
  plt.imshow(data,cmap='nipy_spectral')
  plt.colorbar()
  plt.axis('off')
  plt.show()

plot_gt(gt)

# %%
plot_gt(gt_2)
